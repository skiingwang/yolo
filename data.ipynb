# %%
import matplotlib.pyplot as plt, paddle, paddle.vision.transforms as T
from paddle.io import DataLoader
from dataset import YoloDataset, collate_fn

# %%
ds = YoloDataset('../data/Drink_284_Detection', transform=T.ToTensor())

train_loader = DataLoader(ds, batch_size=3, shuffle=True, collate_fn=collate_fn)

# %%
d = next(iter(train_loader))
d[1]
# Out:
# [Tensor(shape=[5], dtype=int64, place=Place(cpu), stop_gradient=True,
#         [8, 4, 3, 2, 0]),
#  Tensor(shape=[3], dtype=int64, place=Place(cpu), stop_gradient=True,
#         [7, 4, 1]),
#  Tensor(shape=[6], dtype=int64, place=Place(cpu), stop_gradient=True,
#         [8, 9, 5, 3, 2, 0])]
